# %% [markdown]
# # Faces recognition using LLE and SVMs
#
#
# The dataset used in this example is a preprocessed excerpt of the
# "Labeled Faces in the Wild", aka LFW_:
#
#   http://vis-www.cs.umass.edu/lfw/lfw-funneled.tgz (233MB)
#
#   LFW: http://vis-www.cs.umass.edu/lfw/

# %%
# %matplotlib inline
from time import time
import logging
import matplotlib.pyplot as plt

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import fetch_lfw_people
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn import manifold

print(__doc__)

# Display progress logs on stdout
logging.basicConfig(level=logging.INFO, format='%(asctime)s %(message)s')

lfw_people = fetch_lfw_people(min_faces_per_person=70, resize=0.4)

# introspect the images arrays to find the shapes (for plotting)
n_samples, h, w = lfw_people.images.shape

# for machine learning we use the 2 data directly (as relative pixel
# positions info is ignored by this model)
X = lfw_people.data
n_features = X.shape[1]

# the label to predict is the id of the person
y = lfw_people.target
target_names = lfw_people.target_names
n_classes = target_names.shape[0]

print("Total dataset size:")
print("n_samples: %d" % n_samples)
print("n_features: %d" % n_features)
print("n_classes: %d" % n_classes)

# split into a training and testing set
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42)
# Out:
# 2017-03-17 22:09:55,833 Loading LFW people faces from /home/chandu/scikit_learn_data/lfw_home
# Automatically created module for IPython interactive environment
# Total dataset size:
# n_samples: 1288
# n_features: 1850
# n_classes: 7

# %%
methods = ['standard', 'ltsa', 'hessian', 'modified']
accuracies = []
components = []
neighbors = []
for nn in xrange(2,30,2):
    n_components = nn
    for nnj in xrange(nn+1,30,2):
        n_neighbors = nnj

        lle = manifold.LocallyLinearEmbedding(n_neighbors, n_components,eigen_solver='auto',method=methods[0])

        X_train_changed = lle.fit_transform(X_train)
        X_test_changed = lle.fit_transform(X_test)
        param_grid = {'C': [1,1e1,1e2,5e2,1e3, 5e3, 1e4, 5e4, 1e5],
                              'gamma': [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.1], }
        clf = GridSearchCV(SVC(kernel='rbf', class_weight='balanced'), param_grid)
        clf = clf.fit(X_train_changed, y_train)
        y_pred = clf.predict(X_test_changed)

        accuracies.append(float(np.sum(y_test==y_pred))/len(y_pred))
        components.append(n_components)
        neighbors.append(n_neighbors)

        print('For '+str(n_components)+' components '+str(n_neighbors)+' neighbors'+', accuracy is '+str(float(np.sum(y_test==y_pred))/len(y_pred))+' confusion matrix is: ')
        print(confusion_matrix(y_test, y_pred, labels=range(n_classes)))
        print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# For 2 components 3 neighbors, accuracy is 0.055900621118 confusion matrix is:
# [[  0   0   2   0   0  11   0]
#  [  0   0  15   0   0  45   0]
#  [  0   0   7   0   0  20   0]
#  [  0   0  17   0   0 129   0]
#  [  0   0   5   0   0  20   0]
#  [  0   0   4   0   0  11   0]
#  [  0   0  13   0   0  23   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.11      0.26      0.16        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.04      0.73      0.08        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.01      0.06      0.02       322
# /home/chandu/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# For 2 components 5 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 2 components 7 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 2 components 9 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 2 components 11 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 2 components 13 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 2 components 15 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 2 components 17 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 2 components 19 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 2 components 21 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 2 components 23 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 2 components 25 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 2 components 27 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 2 components 29 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 4 components 5 neighbors, accuracy is 0.130434782609 confusion matrix is:
# [[ 6  2  2  0  0  3  0]
#  [21 23  9  0  0  7  0]
#  [ 9  9  7  0  0  2  0]
#  [67 27 31  0  2 15  4]
#  [ 8  7  4  0  0  4  2]
#  [ 9  4  0  0  0  2  0]
#  [ 9 12  5  0  0  6  4]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.05      0.46      0.08        13
#      Colin Powell       0.27      0.38      0.32        60
#   Donald Rumsfeld       0.12      0.26      0.16        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      0.13      0.07        15
#        Tony Blair       0.40      0.11      0.17        36
#
#       avg / total       0.11      0.13      0.10       322
#
# For 4 components 7 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 4 components 9 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 4 components 11 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 4 components 13 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 4 components 15 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 4 components 17 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 4 components 19 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 4 components 21 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 4 components 23 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 4 components 25 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 4 components 27 neighbors, accuracy is 0.0900621118012 confusion matrix is:
# [[  0   0  12   0   0   1   0]
#  [  1   0  36   0   0  23   0]
#  [  0   0  20   0   0   7   0]
#  [  8   0 106   0   0  32   0]
#  [  0   0  16   0   0   9   0]
#  [  0   0   6   0   0   9   0]
#  [  2   0  21   0   0  13   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.09      0.74      0.16        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.10      0.60      0.17        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.01      0.09      0.02       322
#
# For 4 components 29 neighbors, accuracy is 0.0621118012422 confusion matrix is:
# [[ 0  0  9  0  0  4  0]
#  [ 1  0 42  0  0 17  0]
#  [ 0  0 17  0  0 10  0]
#  [ 6  0 85  3  0 52  0]
#  [ 0  0 13  1  0 11  0]
#  [ 0  0 15  0  0  0  0]
#  [ 1  0 25  1  0  9  0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.08      0.63      0.15        27
#     George W Bush       0.60      0.02      0.04       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.00      0.00      0.00        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.28      0.06      0.03       322
#
# For 6 components 7 neighbors, accuracy is 0.155279503106 confusion matrix is:
# [[ 0  2  1  2  2  4  2]
#  [ 2 14  2 22  7  8  5]
#  [ 3  3  3  5  2  3  8]
#  [24 25 31 22 13 14 17]
#  [ 3  9  2  3  2  2  4]
#  [ 2  1  1  2  3  2  4]
#  [ 2  6  2 12  4  3  7]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.23      0.23      0.23        60
#   Donald Rumsfeld       0.07      0.11      0.09        27
#     George W Bush       0.32      0.15      0.21       146
# Gerhard Schroeder       0.06      0.08      0.07        25
#       Hugo Chavez       0.06      0.13      0.08        15
#        Tony Blair       0.15      0.19      0.17        36
#
#       avg / total       0.22      0.16      0.17       322
#
# For 6 components 9 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 6 components 11 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 6 components 13 neighbors, accuracy is 0.164596273292 confusion matrix is:
# [[ 1  0  5  2  1  3  1]
#  [11 13  8  3  7  7 11]
#  [ 4  5  4  5  0  6  3]
#  [14 16 15 22 15 42 22]
#  [ 6  4  3  4  1  1  6]
#  [ 0  3  1  3  1  4  3]
#  [ 7  6  2  3  2  8  8]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.02      0.08      0.04        13
#      Colin Powell       0.28      0.22      0.24        60
#   Donald Rumsfeld       0.11      0.15      0.12        27
#     George W Bush       0.52      0.15      0.23       146
# Gerhard Schroeder       0.04      0.04      0.04        25
#       Hugo Chavez       0.06      0.27      0.09        15
#        Tony Blair       0.15      0.22      0.18        36
#
#       avg / total       0.32      0.16      0.19       322
#
# For 6 components 15 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 6 components 17 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 6 components 19 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 6 components 21 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 6 components 23 neighbors, accuracy is 0.229813664596 confusion matrix is:
# [[ 3  0  0  2  3  4  1]
#  [ 9  6  7 16 12  7  3]
#  [ 5  0  1 10  7  1  3]
#  [32 15  8 49 13  8 21]
#  [ 3  1  5  3  5  1  7]
#  [ 5  0  2  5  1  2  0]
#  [ 7  1  1 12  6  1  8]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.05      0.23      0.08        13
#      Colin Powell       0.26      0.10      0.14        60
#   Donald Rumsfeld       0.04      0.04      0.04        27
#     George W Bush       0.51      0.34      0.40       146
# Gerhard Schroeder       0.11      0.20      0.14        25
#       Hugo Chavez       0.08      0.13      0.10        15
#        Tony Blair       0.19      0.22      0.20        36
#
#       avg / total       0.32      0.23      0.25       322
#
# For 6 components 25 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 6 components 27 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 6 components 29 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 8 components 9 neighbors, accuracy is 0.245341614907 confusion matrix is:
# [[ 2  3  2  2  2  0  2]
#  [ 4 23  2 20  3  4  4]
#  [ 1 15  0  9  1  1  0]
#  [19 36  4 49 12  2 24]
#  [ 0 10  0  9  3  1  2]
#  [ 2  4  0  7  0  2  0]
#  [ 1 17  1 11  5  1  0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.07      0.15      0.10        13
#      Colin Powell       0.21      0.38      0.27        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.46      0.34      0.39       146
# Gerhard Schroeder       0.12      0.12      0.12        25
#       Hugo Chavez       0.18      0.13      0.15        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.27      0.25      0.25       322
#
# For 8 components 11 neighbors, accuracy is 0.214285714286 confusion matrix is:
# [[ 4  2  4  1  0  1  1]
#  [15 18 11  9  2  0  5]
#  [ 2 13  6  4  0  1  1]
#  [31 16 14 36  5  9 35]
#  [ 7  3  6  2  3  0  4]
#  [ 3  1  3  6  0  0  2]
#  [ 3 11  9  6  4  1  2]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.06      0.31      0.10        13
#      Colin Powell       0.28      0.30      0.29        60
#   Donald Rumsfeld       0.11      0.22      0.15        27
#     George W Bush       0.56      0.25      0.34       146
# Gerhard Schroeder       0.21      0.12      0.15        25
#       Hugo Chavez       0.00      0.00      0.00        15
#        Tony Blair       0.04      0.06      0.05        36
#
#       avg / total       0.34      0.21      0.24       322
#
# For 8 components 13 neighbors, accuracy is 0.16149068323 confusion matrix is:
# [[ 2  1  3  6  0  1  0]
#  [ 5  2 10 28  7  5  3]
#  [ 3  2  0 20  1  1  0]
#  [52 21  4 40 11  4 14]
#  [ 5  0  0 13  3  2  2]
#  [ 2  3  1  2  3  2  2]
#  [ 2  3  3 20  3  2  3]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.03      0.15      0.05        13
#      Colin Powell       0.06      0.03      0.04        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.31      0.27      0.29       146
# Gerhard Schroeder       0.11      0.12      0.11        25
#       Hugo Chavez       0.12      0.13      0.12        15
#        Tony Blair       0.12      0.08      0.10        36
#
#       avg / total       0.18      0.16      0.17       322
#
# For 8 components 15 neighbors, accuracy is 0.17701863354 confusion matrix is:
# [[ 1  1  4  2  2  2  1]
#  [ 9  2  4 25  8  7  5]
#  [ 4  0  1  7  8  4  3]
#  [21  1 34 38 32 12  8]
#  [ 3  1  0 10  9  1  1]
#  [ 7  1  0  3  1  3  0]
#  [ 3  1  1 20  4  4  3]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.02      0.08      0.03        13
#      Colin Powell       0.29      0.03      0.06        60
#   Donald Rumsfeld       0.02      0.04      0.03        27
#     George W Bush       0.36      0.26      0.30       146
# Gerhard Schroeder       0.14      0.36      0.20        25
#       Hugo Chavez       0.09      0.20      0.13        15
#        Tony Blair       0.14      0.08      0.11        36
#
#       avg / total       0.25      0.18      0.19       322
#
# For 8 components 17 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 8 components 19 neighbors, accuracy is 0.201863354037 confusion matrix is:
# [[ 0  0  4  1  1  3  4]
#  [ 5  2 13 12 14  4 10]
#  [ 0  1  2 15  6  0  3]
#  [ 7  2 21 50 22  4 40]
#  [ 0  2  5  4  7  3  4]
#  [ 2  0  2  3  3  0  5]
#  [ 1  0  2  9 17  3  4]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.29      0.03      0.06        60
#   Donald Rumsfeld       0.04      0.07      0.05        27
#     George W Bush       0.53      0.34      0.42       146
# Gerhard Schroeder       0.10      0.28      0.15        25
#       Hugo Chavez       0.00      0.00      0.00        15
#        Tony Blair       0.06      0.11      0.08        36
#
#       avg / total       0.31      0.20      0.22       322
#
# For 8 components 21 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 8 components 23 neighbors, accuracy is 0.164596273292 confusion matrix is:
# [[ 1  1  2  6  1  1  1]
#  [ 5  0  4 32  5 10  4]
#  [ 2  1  1  9  6  4  4]
#  [12 12 14 44 52  8  4]
#  [ 1  4  1 11  5  2  1]
#  [ 2  0  6  4  3  0  0]
#  [ 6  0  4 16  4  4  2]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.03      0.08      0.05        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.03      0.04      0.03        27
#     George W Bush       0.36      0.30      0.33       146
# Gerhard Schroeder       0.07      0.20      0.10        25
#       Hugo Chavez       0.00      0.00      0.00        15
#        Tony Blair       0.12      0.06      0.08        36
#
#       avg / total       0.19      0.16      0.17       322
#
# For 8 components 25 neighbors, accuracy is 0.17701863354 confusion matrix is:
# [[ 3  0  2  5  0  2  1]
#  [ 5  0  3 24  8 12  8]
#  [ 5  2  2 10  2  2  4]
#  [12 26  8 43 40  9  8]
#  [ 1  3  2 10  4  4  1]
#  [ 1  3  0  6  3  2  0]
#  [ 0  6  2 14  3  8  3]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.11      0.23      0.15        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.11      0.07      0.09        27
#     George W Bush       0.38      0.29      0.33       146
# Gerhard Schroeder       0.07      0.16      0.09        25
#       Hugo Chavez       0.05      0.13      0.07        15
#        Tony Blair       0.12      0.08      0.10        36
#
#       avg / total       0.21      0.18      0.19       322
#
# For 8 components 27 neighbors, accuracy is 0.195652173913 confusion matrix is:
# [[ 3  0  1  0  5  3  1]
#  [ 6  4  0 37  8  4  1]
#  [ 3  4  2 11  3  3  1]
#  [14 17  8 44 42 21  0]
#  [ 2  1  1 14  6  1  0]
#  [ 1  0  1  7  3  3  0]
#  [ 2  2  4 20  4  3  1]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.10      0.23      0.14        13
#      Colin Powell       0.14      0.07      0.09        60
#   Donald Rumsfeld       0.12      0.07      0.09        27
#     George W Bush       0.33      0.30      0.32       146
# Gerhard Schroeder       0.08      0.24      0.12        25
#       Hugo Chavez       0.08      0.20      0.11        15
#        Tony Blair       0.25      0.03      0.05        36
#
#       avg / total       0.23      0.20      0.19       322
#
# For 8 components 29 neighbors, accuracy is 0.170807453416 confusion matrix is:
# [[ 1  0  0  6  1  3  2]
#  [ 3  5  3 29  5  8  7]
#  [ 2  3  0 14  4  1  3]
#  [13  8 10 39 34 10 32]
#  [ 0  0  2 12  4  3  4]
#  [ 3  0  1  2  4  1  4]
#  [ 2  3  2 11 12  1  5]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.04      0.08      0.05        13
#      Colin Powell       0.26      0.08      0.13        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.35      0.27      0.30       146
# Gerhard Schroeder       0.06      0.16      0.09        25
#       Hugo Chavez       0.04      0.07      0.05        15
#        Tony Blair       0.09      0.14      0.11        36
#
#       avg / total       0.22      0.17      0.18       322
#
# For 10 components 11 neighbors, accuracy is 0.208074534161 confusion matrix is:
# [[ 1  3  0  2  2  2  3]
#  [11 10  7 22  7  3  0]
#  [ 7  4  1 11  4  0  0]
#  [39 27  6 52  4 10  8]
#  [ 6  8  1  7  1  2  0]
#  [ 1  4  0  5  1  1  3]
#  [ 6  7  0 14  7  1  1]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.01      0.08      0.02        13
#      Colin Powell       0.16      0.17      0.16        60
#   Donald Rumsfeld       0.07      0.04      0.05        27
#     George W Bush       0.46      0.36      0.40       146
# Gerhard Schroeder       0.04      0.04      0.04        25
#       Hugo Chavez       0.05      0.07      0.06        15
#        Tony Blair       0.07      0.03      0.04        36
#
#       avg / total       0.26      0.21      0.23       322
#
# For 10 components 13 neighbors, accuracy is 0.16149068323 confusion matrix is:
# [[ 4  1  1  1  4  1  1]
#  [20  6  2 12  6  6  8]
#  [ 3  5  1  9  2  4  3]
#  [12 27 25 37 29  7  9]
#  [ 8  3  3  5  2  1  3]
#  [ 4  1  1  4  3  1  1]
#  [12  5  1 11  2  4  1]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.06      0.31      0.11        13
#      Colin Powell       0.12      0.10      0.11        60
#   Donald Rumsfeld       0.03      0.04      0.03        27
#     George W Bush       0.47      0.25      0.33       146
# Gerhard Schroeder       0.04      0.08      0.05        25
#       Hugo Chavez       0.04      0.07      0.05        15
#        Tony Blair       0.04      0.03      0.03        36
#
#       avg / total       0.25      0.16      0.19       322
#
# For 10 components 15 neighbors, accuracy is 0.170807453416 confusion matrix is:
# [[ 1  1  1  2  4  3  1]
#  [ 6  6  4 19 16  8  1]
#  [ 3  1  0 11  9  3  0]
#  [35  4 18 39 21 22  7]
#  [ 2  0  2 11  7  3  0]
#  [ 1  3  3  2  1  2  3]
#  [ 2  2  1 17  8  6  0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.02      0.08      0.03        13
#      Colin Powell       0.35      0.10      0.16        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.39      0.27      0.32       146
# Gerhard Schroeder       0.11      0.28      0.15        25
#       Hugo Chavez       0.04      0.13      0.06        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.25      0.17      0.19       322
#
# For 10 components 17 neighbors, accuracy is 0.0465838509317 confusion matrix is:
# [[  0   0   0   0   0  13   0]
#  [  0   0   0   0   0  60   0]
#  [  0   0   0   0   0  27   0]
#  [  0   0   0   0   0 146   0]
#  [  0   0   0   0   0  25   0]
#  [  0   0   0   0   0  15   0]
#  [  0   0   0   0   0  36   0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.00      0.00      0.00        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.00      0.00      0.00       146
# Gerhard Schroeder       0.00      0.00      0.00        25
#       Hugo Chavez       0.05      1.00      0.09        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.00      0.05      0.00       322
#
# For 10 components 19 neighbors, accuracy is 0.16149068323 confusion matrix is:
# [[ 1  2  4  3  1  1  1]
#  [ 2  2 10 30  8  6  2]
#  [ 3  0  2 12  7  1  2]
#  [14 21 17 37 41 10  6]
#  [ 2  2  4 12  3  0  2]
#  [ 2  0  1  5  3  4  0]
#  [ 6  1  2 15  9  0  3]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.03      0.08      0.05        13
#      Colin Powell       0.07      0.03      0.05        60
#   Donald Rumsfeld       0.05      0.07      0.06        27
#     George W Bush       0.32      0.25      0.28       146
# Gerhard Schroeder       0.04      0.12      0.06        25
#       Hugo Chavez       0.18      0.27      0.22        15
#        Tony Blair       0.19      0.08      0.12        36
#
#       avg / total       0.20      0.16      0.17       322
#
# For 10 components 21 neighbors, accuracy is 0.267080745342 confusion matrix is:
# [[ 0  2  4  2  2  2  1]
#  [ 1 15  7 14 14  6  3]
#  [ 1  3  1 11  8  3  0]
#  [ 4 10 15 61 21 12 23]
#  [ 0  3  0 12  7  1  2]
#  [ 0  2  1  5  3  2  2]
#  [ 1  5  2  9 19  0  0]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.38      0.25      0.30        60
#   Donald Rumsfeld       0.03      0.04      0.04        27
#     George W Bush       0.54      0.42      0.47       146
# Gerhard Schroeder       0.09      0.28      0.14        25
#       Hugo Chavez       0.08      0.13      0.10        15
#        Tony Blair       0.00      0.00      0.00        36
#
#       avg / total       0.33      0.27      0.29       322
#
# For 10 components 23 neighbors, accuracy is 0.211180124224 confusion matrix is:
# [[ 4  0  2  3  1  2  1]
#  [13  4  4 24  5  7  3]
#  [11  1  1  7  4  2  1]
#  [17 13  8 46 53  5  4]
#  [ 1  2  1 11  7  1  2]
#  [ 2  1  1  5  2  3  1]
#  [ 3  6  2 14  6  2  3]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.08      0.31      0.12        13
#      Colin Powell       0.15      0.07      0.09        60
#   Donald Rumsfeld       0.05      0.04      0.04        27
#     George W Bush       0.42      0.32      0.36       146
# Gerhard Schroeder       0.09      0.28      0.14        25
#       Hugo Chavez       0.14      0.20      0.16        15
#        Tony Blair       0.20      0.08      0.12        36
#
#       avg / total       0.26      0.21      0.22       322
#
# For 10 components 25 neighbors, accuracy is 0.229813664596 confusion matrix is:
# [[ 4  1  0  0  3  4  1]
#  [ 1  4  6  9 14 13 13]
#  [ 3  0  2 10  7  3  2]
#  [32 16 17 47 12 14  8]
#  [ 4  4  3  3  6  2  3]
#  [ 2  1  4  5  0  3  0]
#  [ 0  4  5 12  3  4  8]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.09      0.31      0.14        13
#      Colin Powell       0.13      0.07      0.09        60
#   Donald Rumsfeld       0.05      0.07      0.06        27
#     George W Bush       0.55      0.32      0.41       146
# Gerhard Schroeder       0.13      0.24      0.17        25
#       Hugo Chavez       0.07      0.20      0.10        15
#        Tony Blair       0.23      0.22      0.23        36
#
#       avg / total       0.32      0.23      0.25       322
#
# For 10 components 27 neighbors, accuracy is 0.170807453416 confusion matrix is:
# [[ 2  0  0  9  0  1  1]
#  [ 1  6  3 40  4  3  3]
#  [ 3  7  2  9  2  0  4]
#  [ 8 27  3 32 50 17  9]
#  [ 4  2  2 10  6  1  0]
#  [ 0  0  0  6  3  5  1]
#  [ 6  2  1 12 11  2  2]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.08      0.15      0.11        13
#      Colin Powell       0.14      0.10      0.12        60
# ...
#     George W Bush       0.53      0.48      0.50       146
# Gerhard Schroeder       0.08      0.20      0.11        25
#       Hugo Chavez       0.12      0.13      0.12        15
#        Tony Blair       0.18      0.11      0.14        36
#
#       avg / total       0.32      0.29      0.30       322
#
# For 18 components 21 neighbors, accuracy is 0.257763975155 confusion matrix is:
# [[ 1  0  2  5  1  4  0]
#  [ 4  7  3 28  3 12  3]
#  [ 1  7  0 13  4  2  0]
#  [ 7 13  5 66 21  7 27]
#  [ 1  2  1 12  5  4  0]
#  [ 0  1  1  6  4  1  2]
#  [ 2  6  0  9 12  4  3]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.06      0.08      0.07        13
#      Colin Powell       0.19      0.12      0.15        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.47      0.45      0.46       146
# Gerhard Schroeder       0.10      0.20      0.13        25
#       Hugo Chavez       0.03      0.07      0.04        15
#        Tony Blair       0.09      0.08      0.08        36
#
#       avg / total       0.27      0.26      0.26       322
#
# For 18 components 23 neighbors, accuracy is 0.332298136646 confusion matrix is:
# [[ 2  0  0 10  1  0  0]
#  [ 5  8  5 27  6  7  2]
#  [ 3  5  2  7  9  0  1]
#  [ 6 13  5 82 31  0  9]
#  [ 1  1  1 12  7  0  3]
#  [ 0  1  0 10  3  1  0]
#  [ 3  0  1 13 11  3  5]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.10      0.15      0.12        13
#      Colin Powell       0.29      0.13      0.18        60
#   Donald Rumsfeld       0.14      0.07      0.10        27
#     George W Bush       0.51      0.56      0.53       146
# Gerhard Schroeder       0.10      0.28      0.15        25
#       Hugo Chavez       0.09      0.07      0.08        15
#        Tony Blair       0.25      0.14      0.18        36
#
#       avg / total       0.34      0.33      0.32       322
#
# For 18 components 25 neighbors, accuracy is 0.301242236025 confusion matrix is:
# [[ 0  2  0  2  5  2  2]
#  [ 1  7  3 17 14  9  9]
#  [ 0  4  2 14  5  0  2]
#  [ 7 16 12 72 24  3 12]
#  [ 1  2  2  4 12  0  4]
#  [ 1  2  2  8  1  1  0]
#  [ 0  3  7 15  6  2  3]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.19      0.12      0.15        60
#   Donald Rumsfeld       0.07      0.07      0.07        27
#     George W Bush       0.55      0.49      0.52       146
# Gerhard Schroeder       0.18      0.48      0.26        25
#       Hugo Chavez       0.06      0.07      0.06        15
#        Tony Blair       0.09      0.08      0.09        36
#
#       avg / total       0.32      0.30      0.30       322
#
# For 18 components 27 neighbors, accuracy is 0.270186335404 confusion matrix is:
# [[ 0  2  0  7  1  0  3]
#  [ 1  9  0 40  5  3  2]
#  [ 1  6  2  8  3  0  7]
#  [ 3 13  6 69 40  2 13]
#  [ 0  0  0 19  3  1  2]
#  [ 0  1  1  7  4  2  0]
#  [ 0  2  3 15 13  1  2]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.27      0.15      0.19        60
#   Donald Rumsfeld       0.17      0.07      0.10        27
#     George W Bush       0.42      0.47      0.44       146
# Gerhard Schroeder       0.04      0.12      0.06        25
#       Hugo Chavez       0.22      0.13      0.17        15
#        Tony Blair       0.07      0.06      0.06        36
#
#       avg / total       0.28      0.27      0.27       322
#
# For 18 components 29 neighbors, accuracy is 0.301242236025 confusion matrix is:
# [[ 0  4  0  3  3  2  1]
#  [ 3  8  2 31  6  2  8]
#  [ 2  2  2 11  8  2  0]
#  [ 5 13  6 72 28  4 18]
#  [ 0  5  0 12  4  1  3]
#  [ 0  1  0  8  3  2  1]
#  [ 2  3  3 13  5  1  9]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.22      0.13      0.17        60
#   Donald Rumsfeld       0.15      0.07      0.10        27
#     George W Bush       0.48      0.49      0.49       146
# Gerhard Schroeder       0.07      0.16      0.10        25
#       Hugo Chavez       0.14      0.13      0.14        15
#        Tony Blair       0.23      0.25      0.24        36
#
#       avg / total       0.31      0.30      0.30       322
#
# For 20 components 21 neighbors, accuracy is 0.276397515528 confusion matrix is:
# [[ 0  1  0  6  1  5  0]
#  [ 3 10  3 31  5  5  3]
#  [ 0  4  0 14  7  2  0]
#  [ 9 15  3 69 20  5 25]
#  [ 1  5  1 10  8  0  0]
#  [ 0  1  1  6  4  1  2]
#  [ 1  8  0 10 15  1  1]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.23      0.17      0.19        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.47      0.47      0.47       146
# Gerhard Schroeder       0.13      0.32      0.19        25
#       Hugo Chavez       0.05      0.07      0.06        15
#        Tony Blair       0.03      0.03      0.03        36
#
#       avg / total       0.27      0.28      0.27       322
#
# For 20 components 23 neighbors, accuracy is 0.33850931677 confusion matrix is:
# [[ 3  1  0  8  0  0  1]
#  [ 3 12  3 30  6  4  2]
#  [ 3  6  2  8  7  1  0]
#  [ 9 10  8 79 28  1 11]
#  [ 3  1  1 13  4  0  3]
#  [ 0  1  0  9  4  1  0]
#  [ 1  3  1 16  6  1  8]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.14      0.23      0.17        13
#      Colin Powell       0.35      0.20      0.26        60
#   Donald Rumsfeld       0.13      0.07      0.10        27
#     George W Bush       0.48      0.54      0.51       146
# Gerhard Schroeder       0.07      0.16      0.10        25
#       Hugo Chavez       0.12      0.07      0.09        15
#        Tony Blair       0.32      0.22      0.26        36
#
#       avg / total       0.35      0.34      0.34       322
#
# For 20 components 25 neighbors, accuracy is 0.276397515528 confusion matrix is:
# [[ 0  2  0  2  5  2  2]
#  [ 1  6  1 22 15  6  9]
#  [ 1  3  2 10  6  1  4]
#  [18 12  9 69 24  2 12]
#  [ 0  2  3 10  6  2  2]
#  [ 1  3  3  7  0  1  0]
#  [ 0  4  8 15  3  1  5]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.19      0.10      0.13        60
#   Donald Rumsfeld       0.08      0.07      0.08        27
#     George W Bush       0.51      0.47      0.49       146
# Gerhard Schroeder       0.10      0.24      0.14        25
#       Hugo Chavez       0.07      0.07      0.07        15
#        Tony Blair       0.15      0.14      0.14        36
#
#       avg / total       0.30      0.28      0.28       322
#
# For 20 components 27 neighbors, accuracy is 0.285714285714 confusion matrix is:
# [[ 0  2  1  7  1  0  2]
#  [ 0 11  1 35  8  2  3]
#  [ 1  4  2  9  2  0  9]
#  [ 3  9  4 72 48  1  9]
#  [ 0  0  1 19  3  1  1]
#  [ 0  3  0  6  5  1  0]
#  [ 0  2  2 15 12  2  3]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.35      0.18      0.24        60
#   Donald Rumsfeld       0.18      0.07      0.11        27
#     George W Bush       0.44      0.49      0.47       146
# Gerhard Schroeder       0.04      0.12      0.06        25
#       Hugo Chavez       0.14      0.07      0.09        15
#        Tony Blair       0.11      0.08      0.10        36
#
#       avg / total       0.30      0.29      0.28       322
#
# For 20 components 29 neighbors, accuracy is 0.291925465839 confusion matrix is:
# [[ 2  5  0  2  2  2  0]
#  [ 1  8  1 30 10  3  7]
#  [ 2  1  3  8 10  2  1]
#  [ 3 22  5 71 28  2 15]
#  [ 0  5  0 13  4  1  2]
#  [ 0  2  1  7  3  1  1]
#  [ 1  4  1 17  8  0  5]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.22      0.15      0.18        13
#      Colin Powell       0.17      0.13      0.15        60
#   Donald Rumsfeld       0.27      0.11      0.16        27
#     George W Bush       0.48      0.49      0.48       146
# Gerhard Schroeder       0.06      0.16      0.09        25
#       Hugo Chavez       0.09      0.07      0.08        15
#        Tony Blair       0.16      0.14      0.15        36
#
#       avg / total       0.31      0.29      0.29       322
#
# For 22 components 23 neighbors, accuracy is 0.313664596273 confusion matrix is:
# [[ 1  1  1  7  1  0  2]
#  [ 3  8  4 30  5  4  6]
#  [ 1  7  0 13  4  0  2]
#  [ 6  7 10 78 31  2 12]
#  [ 1  1  0 13  5  1  4]
#  [ 0  0  0 11  3  1  0]
#  [ 0  4  2 17  5  0  8]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.08      0.08      0.08        13
#      Colin Powell       0.29      0.13      0.18        60
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.46      0.53      0.50       146
# Gerhard Schroeder       0.09      0.20      0.13        25
#       Hugo Chavez       0.12      0.07      0.09        15
#        Tony Blair       0.24      0.22      0.23        36
#
#       avg / total       0.31      0.31      0.30       322
#
# For 22 components 25 neighbors, accuracy is 0.298136645963 confusion matrix is:
# [[ 0  2  0  1  5  2  3]
#  [ 0  8  0 23 18  3  8]
#  [ 1  2  2 12  4  3  3]
#  [16 12  9 74 21  3 11]
#  [ 0  2  3  8  7  1  4]
#  [ 2  2  2  8  1  0  0]
#  [ 0  4  5 16  6  0  5]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.25      0.13      0.17        60
#   Donald Rumsfeld       0.10      0.07      0.08        27
#     George W Bush       0.52      0.51      0.51       146
# Gerhard Schroeder       0.11      0.28      0.16        25
#       Hugo Chavez       0.00      0.00      0.00        15
#        Tony Blair       0.15      0.14      0.14        36
#
#       avg / total       0.32      0.30      0.30       322
#
# For 22 components 27 neighbors, accuracy is 0.291925465839 confusion matrix is:
# [[ 0  2  1  6  2  0  2]
#  [ 0  9  2 37  7  2  3]
#  [ 1  4  2 10  2  0  8]
#  [ 2  9  4 77 41  1 12]
#  [ 0  0  0 21  3  1  0]
#  [ 0  1  1  8  4  1  0]
#  [ 1  2  2 17 12  0  2]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.33      0.15      0.21        60
#   Donald Rumsfeld       0.17      0.07      0.10        27
#     George W Bush       0.44      0.53      0.48       146
# Gerhard Schroeder       0.04      0.12      0.06        25
#       Hugo Chavez       0.20      0.07      0.10        15
#        Tony Blair       0.07      0.06      0.06        36
#
#       avg / total       0.30      0.29      0.28       322
#
# For 22 components 29 neighbors, accuracy is 0.298136645963 confusion matrix is:
# [[ 2  5  0  3  1  2  0]
#  [ 1  8  1 27 11  4  8]
#  [ 2  1  1  9 11  2  1]
#  [ 7 19  4 76 21  2 17]
#  [ 1  4  0 13  4  1  2]
#  [ 0  2  1  7  4  0  1]
#  [ 2  4  2 20  3  0  5]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.13      0.15      0.14        13
#      Colin Powell       0.19      0.13      0.16        60
#   Donald Rumsfeld       0.11      0.04      0.06        27
#     George W Bush       0.49      0.52      0.50       146
# Gerhard Schroeder       0.07      0.16      0.10        25
#       Hugo Chavez       0.00      0.00      0.00        15
#        Tony Blair       0.15      0.14      0.14        36
#
#       avg / total       0.29      0.30      0.29       322
#
# For 24 components 25 neighbors, accuracy is 0.316770186335 confusion matrix is:
# [[ 0  3  0  3  5  1  1]
#  [ 2  9  1 23 16  1  8]
#  [ 0  4  2 14  5  0  2]
#  [12 14  8 78 26  2  6]
#  [ 0  1  3 10  6  1  4]
#  [ 2  1  2  7  1  2  0]
#  [ 1  3  6 17  4  0  5]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.26      0.15      0.19        60
#   Donald Rumsfeld       0.09      0.07      0.08        27
#     George W Bush       0.51      0.53      0.52       146
# Gerhard Schroeder       0.10      0.24      0.14        25
#       Hugo Chavez       0.29      0.13      0.18        15
#        Tony Blair       0.19      0.14      0.16        36
#
#       avg / total       0.33      0.32      0.32       322
#
# For 24 components 27 neighbors, accuracy is 0.298136645963 confusion matrix is:
# [[ 1  1  0  7  1  0  3]
#  [ 0 12  2 37  6  1  2]
#  [ 2  4  1 12  2  0  6]
#  [ 2 11  2 76 39  1 15]
#  [ 0  0  0 19  3  1  2]
#  [ 0  1  1 10  3  0  0]
#  [ 2  1  3 16 10  1  3]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.14      0.08      0.10        13
#      Colin Powell       0.40      0.20      0.27        60
#   Donald Rumsfeld       0.11      0.04      0.06        27
#     George W Bush       0.43      0.52      0.47       146
# Gerhard Schroeder       0.05      0.12      0.07        25
#       Hugo Chavez       0.00      0.00      0.00        15
#        Tony Blair       0.10      0.08      0.09        36
#
#       avg / total       0.30      0.30      0.29       322
#
# For 24 components 29 neighbors, accuracy is 0.332298136646 confusion matrix is:
# [[ 2  3  0  4  2  1  1]
#  [ 1  9  2 29  9  4  6]
#  [ 2  1  2  8 11  2  1]
#  [ 4 22  3 82 18  4 13]
#  [ 2  3  1 13  5  1  0]
#  [ 0  2  0  7  3  1  2]
#  [ 2  4  2 20  2  0  6]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.15      0.15      0.15        13
#      Colin Powell       0.20      0.15      0.17        60
#   Donald Rumsfeld       0.20      0.07      0.11        27
#     George W Bush       0.50      0.56      0.53       146
# Gerhard Schroeder       0.10      0.20      0.13        25
#       Hugo Chavez       0.08      0.07      0.07        15
#        Tony Blair       0.21      0.17      0.18        36
#
#       avg / total       0.32      0.33      0.32       322
#
# For 26 components 27 neighbors, accuracy is 0.33850931677 confusion matrix is:
# [[ 1  1  1  8  1  0  1]
#  [ 2  8  3 39  5  1  2]
#  [ 0  3  3 12  5  0  4]
#  [ 4 14  1 91 27  3  6]
#  [ 0  0  0 22  2  1  0]
#  [ 0  1  0  8  5  1  0]
#  [ 1  0  2 21  9  0  3]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.12      0.08      0.10        13
#      Colin Powell       0.30      0.13      0.18        60
#   Donald Rumsfeld       0.30      0.11      0.16        27
#     George W Bush       0.45      0.62      0.52       146
# Gerhard Schroeder       0.04      0.08      0.05        25
#       Hugo Chavez       0.17      0.07      0.10        15
#        Tony Blair       0.19      0.08      0.12        36
#
#       avg / total       0.32      0.34      0.31       322
#
# For 26 components 29 neighbors, accuracy is 0.310559006211 confusion matrix is:
# [[ 0  2  0  5  4  0  2]
#  [ 1 12  2 28  7  5  5]
#  [ 2  2  1 12  9  1  0]
#  [ 2 23  5 79 15  4 18]
#  [ 3  4  1 13  2  1  1]
#  [ 0  1  0 10  2  1  1]
#  [ 2  2  1 24  2  0  5]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        13
#      Colin Powell       0.26      0.20      0.23        60
#   Donald Rumsfeld       0.10      0.04      0.05        27
#     George W Bush       0.46      0.54      0.50       146
# Gerhard Schroeder       0.05      0.08      0.06        25
#       Hugo Chavez       0.08      0.07      0.07        15
#        Tony Blair       0.16      0.14      0.15        36
#
#       avg / total       0.29      0.31      0.30       322
#
# For 28 components 29 neighbors, accuracy is 0.316770186335 confusion matrix is:
# [[ 2  2  0  3  3  0  3]
#  [ 1  8  1 33 10  4  3]
#  [ 0  2  2 13  8  1  1]
#  [ 1 23  4 84 14  3 17]
#  [ 2  3  0 17  1  1  1]
#  [ 0  1  1  9  2  1  1]
#  [ 3  3  2 21  3  0  4]]
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.22      0.15      0.18        13
#      Colin Powell       0.19      0.13      0.16        60
#   Donald Rumsfeld       0.20      0.07      0.11        27
#     George W Bush       0.47      0.58      0.52       146
# Gerhard Schroeder       0.02      0.04      0.03        25
#       Hugo Chavez       0.10      0.07      0.08        15
#        Tony Blair       0.13      0.11      0.12        36
#
#       avg / total       0.29      0.32      0.30       322

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(neighbors, components, accuracies)
ax.set_xlabel('Neighbors')
ax.set_ylabel('Components')
ax.set_zlabel('Accuracies')
plt.show()
